# %%
import pandas as pd

# %%
currentDir = "https://raw.githubusercontent.com/WAKenney/NWAnalytics/main/"

speciesFile = currentDir + 'NWspecies060222.xlsx'
speciesTable = pd.read_excel(speciesFile,sheet_name = "species")

# %%
spp = speciesTable.loc[:,['species', 'color']]

# %%
colorFile = r"C:\Users\HP\OneDrive\Neighbourwoods\NWAnalytics\NWspecies060222.xlsx"

# %%
colorTable = pd.read_excel(colorFile,sheet_name = "colors")

colorTable.set_index('taxon', inplace = True)

colorTable.head()

colorDict = colorTable.to_dict('dict')

# %%
colorDict['color']
# Out:
# {'Other': 'gray',
#  'Eastern White Cedar': 'aliceblue',
#  'Norway Maple': ' azure',
#  'Honey Locust': ' azure',
#  'Manitoba Maple': ' aquamarine',
#  'Silver Maple': 'olive',
#  'Tree of Heaven': ' black',
#  'White Mulberry': ' bisque',
#  'White Spruce': 'green',
#  'Green Ash': ' blanchedalmond',
#  'Little-Leaf Linden': ' blue',
#  'plantable spot': ' lightcyan',
#  'Common Lilac': ' brown',
#  'White Birch': ' burlywood',
#  'Sugar Maple': ' cadetblue',
#  'Crabapple': ' lightsalmon',
#  'Freman Maple': 'tan',
#  'Red Oak': ' coral',
#  'Siberian Elm': ' cornflowerblue',
#  'Blue Spruce': ' cornsilk',
#  'dead tree': 'brown',
#  'unknown species': ' cyan',
#  'Scotch Elm': ' darkblue',
#  'Austrian Pine': ' darkcyan',
#  'Red Mulberry': ' darkgoldenrod',
#  'Common Horsechestnut': 'teal',
#  'Japanese Tree Lilac': 'thistle',
#  'Japanese Maple': ' darkgreen',
#  'Common Pear': ' darkkhaki',
#  'Red Cedar': ' darkmagenta',
#  'Ginkgo': ' darkcyan',
# ...
