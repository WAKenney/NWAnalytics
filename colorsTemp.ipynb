# %%
import pandas as pd
import streamlit as st

# %%
sppColors = pd.read_excel(r"C:\Users\HP\Desktop\colorsTEMP.xlsx")

# %%
sppColors
# Out:
#   species          color
# 0  aldeur      aliceblue
# 1  aldspe   antiquewhite
# 2  aldspp           aqua
# 3  aldwhi     aquamarine
# 4  amumak          azure

# %%
sppC = sppColors.to_dict('records')

# %%
st.write(sppColors)
